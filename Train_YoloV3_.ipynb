# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Thu Dec 16 09:51:40 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    24W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
#  3-mydiary.jor.mybible
# 'Air purifiers final.doc'
#  BOOKS
# 'Brokerage Firms Target List.gsheet'
#  Classroom
# 'Colab Notebooks'
#  config
# 'Copy of New Sales Report Template 2021.xlsx'
#  covid_impact_on_airport_traffic.csv
# 'Data Analysis Portfolio - to submit.pdf'
# 'Data Cleaning 3.2.gsheet'
# 'Data Cleaning 3.2 - Udemy Courses.xlsx'
# 'Data Cleaning 3.2.xlsx'
# 'Data Science Certificate and Resumee'
# 'DatasetAfricaMalaria (1).gsheet'
#  DatasetAfricaMalaria.csv
#  DatasetAfricaMalaria.gsheet
#  Data_Sheet_Udemy_Courses_-_Business_Courses.csv
#  Data_Sheet_Udemy_Courses_-_Design_Courses.csv
#  Data_Sheet_Udemy_Courses_-_Music_Courses.csv
#  Data_Sheet_Udemy_Courses_-_Music_Courses.gsheet
# 'Data_Sheet_Udemy_Courses_-_Web_Development (1).csv'
# ...

# %% [markdown]
# **1) Clone the Darknet**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %% [markdown]
# **2) Compile Darknet using Nvidia GPU**

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %%
# Create folder on google drive so that we can save there the weights
# !mkdir "/mydrive/yolov3"
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov3’: File exists

# %%
# !echo "Person, Truck, Tanker, Motorcycle, Bicycle" > data/obj.names
# !echo -e "classes= 5\ntrain  = /content/gdrive/MyDrive/Colab\ Notebooks/Traffic\ Surveillance/Custom_data/train.txt\nvalid  = /content/gdrive/MyDrive/Colab\ Notebooks/Traffic\ Surveillance/Custom_data/test.txt\nnames = /content/gdrive/MyDrive/Colab\ Notebooks/Traffic\ Surveillance/Custom_data/classes.names\nbackup = /content/gdrive/MyDrive/Colab\ Notebooks/Traffic\ Surveillance/backup" > data/obj.data
# !mkdir data/obj
# Out:
# mkdir: cannot create directory ‘data/obj’: File exists

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-12-16 09:53:14--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  48.4MB/s    in 3.5s
#
# 2021-12-16 09:53:18 (44.9 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
# !unzip /content/gdrive/MyDrive/Colab\ Notebooks/yolov3/images.zip -d data/obj
# Out:
# Archive:  /content/gdrive/MyDrive/Colab Notebooks/yolov3/images.zip
#    creating: data/obj/Custom_data/test/
#  extracting: data/obj/Custom_data/test/.gitkeep
#   inflating: data/obj/Custom_data/test/traffic.jpg
#   inflating: data/obj/Custom_data/test/traffic.xml
#   inflating: data/obj/Custom_data/test/transportation-and-trucking-a-road-tanker-transporting-bulk-petroleum-B0PGGX.jpg
#   inflating: data/obj/Custom_data/test/transportation-and-trucking-a-road-tanker-transporting-bulk-petroleum-B0PGGX.xml
#   inflating: data/obj/Custom_data/test/trucks-in-traffic.jpg
#   inflating: data/obj/Custom_data/test/trucks-in-traffic.xml
#   inflating: data/obj/Custom_data/test/TrucksOnHighway1.jpg
#   inflating: data/obj/Custom_data/test/TrucksOnHighway1.xml
#   inflating: data/obj/Custom_data/test/Trucks-on-the-road.jpg
#   inflating: data/obj/Custom_data/test/Trucks-on-the-road.xml
#   inflating: data/obj/Custom_data/test/watson-on-unlicensed-riders.jpg
# ...

# %%
# We're going to convert the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
import glob
import os
import re

txt_file_paths = glob.glob(r"data/obj/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
print(images_list)
# Out:
# []

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %% [markdown]
# **6) Start the training**

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_training
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
